# %% [markdown]
# ## Demo

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
from config_manager import ConfigManager
from data_access import DataAccess

schema = ConfigManager.get_config('clustersConfig.schema')
table = ConfigManager.get_config('clustersConfig.table')

bikes = DataAccess().select_to_df(f"SELECT * FROM {schema}.{table}")

bikes
# Out:
#        _id  bikeid                 start_time  duration_minutes  \
# 0   615429     329  2014-10-11 13:12:00+03:00                22
# 1   615430     140  2015-08-08 19:12:00+03:00                12
# 2   615431     220  2015-01-28 18:12:00+02:00                10
# 3   615432     445  2016-03-28 14:41:52+03:00                92
# 4   615433     894  2015-03-07 16:12:00+02:00                44
# ..     ...     ...                        ...               ...
# 95  615524     523  2017-06-16 12:52:00+03:00                45
# 96  615525     696  2015-10-19 17:12:14+03:00                13
# 97  615526     685  2015-09-17 17:12:42+03:00                 5
# 98  615527     518  2016-03-18 15:00:21+02:00                 8
# 99  615528     855  2017-03-19 15:24:58+02:00                40
#
#                        start_station_name  \
# 0         Bullock Museum @ Congress & MLK
# 1   Republic Square @ Guadalupe & 4th St.
# 2                City Hall / Lavaca & 2nd
# 3                    Rainey St @ Cummings
# 4                    Rainey St @ Cummings
# ..                                    ...
# 95          Pfluger Bridge @ W 2nd Street
# 96                            5th & Bowie
# 97            Barton Springs @ Kinney Ave
# 98  Republic Square @ Guadalupe & 4th St.
# 99             Barton Springs & Riverside
#
#                        end_station_name  start_latitude  start_longitude  \
# 0     Capitol Station / Congress & 11th        30.28039        -97.73809
# 1                Davis at Rainey Street        30.26774        -97.74692
# 2                      17th & Guadalupe        30.26476        -97.74678
# 3                  Rainey St @ Cummings        30.25579        -97.73982
# 4                  Rainey St @ Cummings        30.25579        -97.73982
# ..                                  ...             ...              ...
# 95                 Riverside @ S. Lamar        30.26717        -97.75484
# 96                 Rainey St @ Cummings        30.26960        -97.75332
# 97                          Zilker Park        30.26200        -97.76118
# 98               Red River & 8th Street        30.26774        -97.74692
# 99  Long Center @ South 1st & Riverside        30.25870        -97.74872
#
#     end_latitude  end_longitude
# 0       30.27260      -97.74127
# 1       30.26019      -97.73845
# 2       30.27974      -97.74254
# 3       30.25579      -97.73982
# 4       30.25579      -97.73982
# ..           ...            ...
# 95      30.26446      -97.75665
# 96      30.25579      -97.73982
# 97      30.26590      -97.76822
# 98      30.26854      -97.73646
# 99      30.25941      -97.74971
#
# [100 rows x 10 columns]

# %%
from jaccard_workload_approximator import JaccardWorkloadApproximator

workload_approximator = JaccardWorkloadApproximator()
workload = workload_approximator.get_workload_approximation(10)
# Out:
# ============ starting iteration 1   ============
# Processing query:
# SELECT _id FROM public.austin_bikes_100 WHERE end_longitude BETWEEN -97.74816010595596 AND -97.7263877253452
# iteration took: 8.42 ms
# ============ starting iteration 2   ============
# iteration took: 0.53 ms
# ============ starting iteration 3   ============
# iteration took: 0.00 ms
# ============ starting iteration 4   ============
# Processing query:
# SELECT _id FROM public.austin_bikes_100 WHERE end_station_name IN ('5th & San Marcos' , 'Nueces & 3rd' , 'Medina & East 6th' , 'UT West Mall @ Guadalupe' , '5th & Bowie' , '2nd & Congress' , 'ACC - West & 12th Street') AND start_station_name IN ('Barton Springs Pool' , 'Capitol Station / Congress & 11th' , 'Davis at Rainey Street' , 'MoPac Pedestrian Bridge @ Veterans Drive' , 'Republic Square @ Guadalupe & 4th St.' , 'ACC - West & 12th Street' , 'Convention Center / 3rd & Trinity' , 'Rainey St @ Cummings' , 'South Congress & James' , 'Pfluger Bridge @ W 2nd Street' , 'Riverside @ S. Lamar' , 'West & 6th St.' , 'Convention Center / 4th St. @ MetroRail' , '8th & Congress' , 'Long Center @ South 1st & Riverside' , 'East 11th St. & San Marcos' , '5th & San Marcos' , 'Red River & 8th Street' , '17th & Guadalupe' , 'South Congress & Academy' , '8th & Guadalupe' , '5th & Bowie' , 'East 4th & Chicon' , 'Nueces & 3rd' , 'Brazos & 6th' , 'Zilker Park' , '4th & Congress' , 'East 6th & Pedernales St.' , 'UT West Mall @ Guadalupe' , 'Bullock Museum @ Congress & MLK' , 'Barton Springs & Riverside' , 'South Congress & Elizabeth' , 'Plaza Saltillo' , 'Guadalupe & 21st' , 'ACC - Rio Grande & 12th' , 'Palmer Auditorium' , 'Trinity & 6th Street' , '3rd & West' , 'San Jacinto & 8th Street' , 'State Capitol Visitors Garage @ San Jacinto & 12th' , 'City Hall / Lavaca & 2nd')
# iteration took: 0.00 ms
# ============ starting iteration 5   ============
# Processing query:
# SELECT _id FROM public.austin_bikes_100 WHERE start_longitude BETWEEN -97.76224048932843 AND -97.73664047816902 AND end_longitude BETWEEN -97.75524899902041 AND -97.72673788826063 AND start_latitude BETWEEN 30.249710227880996 AND 30.26798994363938
# iteration took: 4.59 ms
# ============ starting iteration 6   ============
# Processing query:
# SELECT _id FROM public.austin_bikes_100 WHERE start_station_name IN ('Davis at Rainey Street' , '8th & Guadalupe' , '5th & Bowie' , '17th & Guadalupe' , 'UT West Mall @ Guadalupe' , 'Republic Square @ Guadalupe & 4th St.' , 'East 6th & Pedernales St.' , 'Palmer Auditorium' , 'City Hall / Lavaca & 2nd' , 'Capitol Station / Congress & 11th' , 'San Jacinto & 8th Street' , 'ACC - Rio Grande & 12th' , 'Trinity & 6th Street' , 'Convention Center / 3rd & Trinity' , 'Plaza Saltillo' , 'Bullock Museum @ Congress & MLK' , 'Guadalupe & 21st' , 'South Congress & Elizabeth' , 'ACC - West & 12th Street' , 'Pfluger Bridge @ W 2nd Street' , 'State Capitol Visitors Garage @ San Jacinto & 12th' , 'Barton Springs & Riverside' , 'South Congress & James' , 'Convention Center / 4th St. @ MetroRail' , '3rd & West' , '2nd & Congress' , '8th & Congress' , 'Waller & 6th St.' , 'Long Center @ South 1st & Riverside' , 'South Congress & Academy' , 'Rainey St @ Cummings' , 'Barton Springs @ Kinney Ave' , 'Red River & 8th Street' , 'Zilker Park' , 'West & 6th St.' , '5th & San Marcos' , 'East 4th & Chicon' , '4th & Congress' , 'Barton Springs Pool') AND bikeid BETWEEN 272.6257605420052 AND 1395.1131767684449 AND start_longitude BETWEEN -97.74652880325179 AND -97.73268925343929
# iteration took: 0.00 ms
# ============ starting iteration 7   ============
# Processing query:
# SELECT _id FROM public.austin_bikes_100 WHERE start_station_name IN ('Barton Springs @ Kinney Ave' , 'Long Center @ South 1st & Riverside' , 'Bullock Museum @ Congress & MLK' , '5th & San Marcos' , 'Capitol Station / Congress & 11th' , 'Barton Springs Pool' , 'Barton Springs & Riverside' , '3rd & West' , 'Zilker Park' , 'ACC - Rio Grande & 12th' , 'Red River & 8th Street' , 'West & 6th St.' , 'Waller & 6th St.' , 'East 11th St. & San Marcos' , '5th & Bowie' , 'San Jacinto & 8th Street' , 'Republic Square @ Guadalupe & 4th St.' , 'Rainey St @ Cummings' , '4th & Congress' , 'East 6th & Pedernales St.' , 'Trinity & 6th Street' , 'Convention Center / 4th St. @ MetroRail' , 'East 4th & Chicon' , 'ACC - West & 12th Street' , 'UT West Mall @ Guadalupe' , 'Pfluger Bridge @ W 2nd Street' , 'Brazos & 6th' , 'Convention Center / 3rd & Trinity' , 'MoPac Pedestrian Bridge @ Veterans Drive' , '8th & Guadalupe' , '17th & Guadalupe' , 'Plaza Saltillo' , 'South Congress & Academy' , 'Davis at Rainey Street' , '2nd & Congress')
# iteration took: 0.00 ms
# ============ starting iteration 8   ============
# Processing query:
# SELECT _id FROM public.austin_bikes_100 WHERE end_longitude BETWEEN -97.76651602817954 AND -97.71772620287089 AND start_station_name IN ('Nueces & 3rd')
# iteration took: 0.00 ms
# ============ starting iteration 9   ============
# Processing query:
# SELECT _id FROM public.austin_bikes_100 WHERE start_station_name IN ('5th & Bowie' , '17th & Guadalupe' , 'East 4th & Chicon' , 'City Hall / Lavaca & 2nd' , 'Nueces & 3rd' , 'Barton Springs Pool' , 'South Congress & James' , 'Pfluger Bridge @ W 2nd Street' , 'Convention Center / 3rd & Trinity' , 'Convention Center / 4th St. @ MetroRail' , 'State Capitol Visitors Garage @ San Jacinto & 12th' , 'ACC - Rio Grande & 12th' , '4th & Congress' , '8th & Guadalupe' , 'Zilker Park' , 'Waller & 6th St.' , 'Barton Springs @ Kinney Ave' , 'Rainey St @ Cummings' , 'Capitol Station / Congress & 11th' , 'South Congress & Academy' , 'Palmer Auditorium' , 'Brazos & 6th' , '8th & Congress' , 'East 11th St. & San Marcos') AND bikeid BETWEEN 190.31561521924183 AND 2403.8094898324807
# iteration took: 0.00 ms
# ============ starting iteration 10   ============
# Processing query:
# SELECT _id FROM public.austin_bikes_100 WHERE start_station_name IN ('Nueces & 3rd' , 'State Capitol Visitors Garage @ San Jacinto & 12th' , 'South Congress & Elizabeth' , 'UT West Mall @ Guadalupe' , 'City Hall / Lavaca & 2nd' , 'Convention Center / 4th St. @ MetroRail' , 'Bullock Museum @ Congress & MLK' , 'Red River & 8th Street' , 'Riverside @ S. Lamar' , 'East 6th & Pedernales St.' , 'West & 6th St.' , 'Davis at Rainey Street' , 'ACC - Rio Grande & 12th' , 'Brazos & 6th' , 'Zilker Park' , 'East 4th & Chicon' , 'South Congress & James' , '2nd & Congress' , 'ACC - West & 12th Street' , 'Convention Center / 3rd & Trinity' , 'Barton Springs Pool' , 'Capitol Station / Congress & 11th' , 'Guadalupe & 21st' , '8th & Guadalupe' , 'South Congress & Academy' , 'Long Center @ South 1st & Riverside' , 'Pfluger Bridge @ W 2nd Street' , 'San Jacinto & 8th Street' , 'Republic Square @ Guadalupe & 4th St.' , '17th & Guadalupe' , '8th & Congress' , 'Barton Springs @ Kinney Ave' , 'Rainey St @ Cummings' , '3rd & West' , '5th & Bowie' , 'MoPac Pedestrian Bridge @ Veterans Drive' , 'Trinity & 6th Street' , 'Barton Springs & Riverside' , 'East 11th St. & San Marcos') AND start_latitude BETWEEN 30.27058156016212 AND 30.283509729099652
# iteration took: 8.03 ms

# %%
import matplotlib.pyplot as plt

DEFAULT_DOT_SIZE = 10

flat = lambda l: [item for sublist in l for item in sublist]
y = flat([[i] * len(workload[i]['result']) for i in range(len(workload))])
x = flat([workload[i]['result'] for i in range(len(workload))])
sizes = flat([[DEFAULT_DOT_SIZE * workload[i]['frequency']] * len(workload[i]['result']) for i in range(len(workload))])

plt.scatter(x, y, s=sizes)
plt.title("Query Workload")
plt.xlabel("tuple id")
plt.ylabel("query id")
plt.show()

# %%
from saqp_manager import SaqpManager

k = 20
saqp_manager = SaqpManager([query['result'] for query in workload], [query['frequency'] for query in workload], k)
sample = saqp_manager.get_sample()
# Out:
# Start running LazyGreedy with type UC
# ============ starting iteration 1   ============
# Updated S, new gain: 183.6836948088430654020864805
# iteration took: 394.04 ms
# ============ starting iteration 2   ============
# Updated S, new gain: 192.1714665490769079001547152
# iteration took: 887.45 ms
# ============ starting iteration 3   ============
# Updated S, new gain: 199.4388611471132680624551677
# iteration took: 85.66 ms
# ============ starting iteration 4   ============
# Updated S, new gain: 204.5783925895568476003601910
# iteration took: 542.14 ms
# ============ starting iteration 5   ============
# Updated S, new gain: 209.4413802070235187210579616
# iteration took: 165.58 ms
# ============ starting iteration 6   ============
# Updated S, new gain: 213.0050394196418669008961280
# iteration took: 929.87 ms
# ============ starting iteration 7   ============
# Updated S, new gain: 216.4678928131970734684069378
# iteration took: 235.71 ms
# ============ starting iteration 8   ============
# Updated S, new gain: 219.4438118209956666374821164
# iteration took: 749.33 ms
# ============ starting iteration 9   ============
# Updated S, new gain: 221.9687248563967855672010347
# iteration took: 466.99 ms
# ============ starting iteration 10   ============
# Updated S, new gain: 224.4214955152101995256260797
# iteration took: 225.26 ms
# ============ starting iteration 11   ============
# Updated S, new gain: 226.6108470925997910252032047
# iteration took: 418.57 ms
# ============ starting iteration 12   ============
# Updated S, new gain: 228.6277714332138335858336105
# iteration took: 693.05 ms
# ============ starting iteration 13   ============
# Updated S, new gain: 230.6122127042408647551211529
# iteration took: 131.58 ms
# ============ starting iteration 14   ============
# Updated S, new gain: 232.4251384887617371690335314
# iteration took: 704.75 ms
# ============ starting iteration 15   ============
# Updated S, new gain: 234.2214577718232008091647858
# iteration took: 111.43 ms
# ============ starting iteration 16   ============
# Updated S, new gain: 235.9791915884922812990898224
# iteration took: 241.54 ms
# ============ starting iteration 17   ============
# Updated S, new gain: 237.6441050567918787156298374
# iteration took: 659.01 ms
# ============ starting iteration 18   ============
# Updated S, new gain: 239.2926555248186416654526910
# iteration took: 251.38 ms
# ============ starting iteration 19   ============
# Updated S, new gain: 240.9382369307034784884317729
# iteration took: 172.84 ms
# ============ starting iteration 20   ============
# Updated S, new gain: 242.5677953743364799896524511
# iteration took: 100.31 ms
# ============ starting iteration 21   ============
# iteration took: 0.00 ms
# LazyGreedy with type UC finished after 21 iterations
# algorithm took: 8166.47 ms
# Start running LazyGreedy with type CB
# ============ starting iteration 1   ============
# Updated S, new gain: 183.6836948088430654020864805
# iteration took: 341.83 ms
# ============ starting iteration 2   ============
# Updated S, new gain: 192.1714665490769079001547152
# iteration took: 819.98 ms
# ============ starting iteration 3   ============
# Updated S, new gain: 199.4388611471132680624551677
# iteration took: 53.20 ms
# ============ starting iteration 4   ============
# Updated S, new gain: 204.5783925895568476003601910
# iteration took: 484.08 ms
# ============ starting iteration 5   ============
# Updated S, new gain: 209.4413802070235187210579616
# iteration took: 117.82 ms
# ============ starting iteration 6   ============
# Updated S, new gain: 213.0050394196418669008961280
# iteration took: 874.06 ms
# ============ starting iteration 7   ============
# Updated S, new gain: 216.4678928131970734684069378
# iteration took: 208.25 ms
# ============ starting iteration 8   ============
# Updated S, new gain: 219.4438118209956666374821164
# iteration took: 583.77 ms
# ============ starting iteration 9   ============
# Updated S, new gain: 221.9687248563967855672010347
# iteration took: 458.16 ms
# ============ starting iteration 10   ============
# Updated S, new gain: 224.4214955152101995256260797
# iteration took: 240.73 ms
# ============ starting iteration 11   ============
# Updated S, new gain: 226.6108470925997910252032047
# iteration took: 410.00 ms
# ============ starting iteration 12   ============
# Updated S, new gain: 228.6277714332138335858336105
# iteration took: 666.11 ms
# ============ starting iteration 13   ============
# Updated S, new gain: 230.6122127042408647551211529
# iteration took: 132.33 ms
# ============ starting iteration 14   ============
# Updated S, new gain: 232.4251384887617371690335314
# iteration took: 758.58 ms
# ============ starting iteration 15   ============
# Updated S, new gain: 234.2214577718232008091647858
# iteration took: 113.85 ms
# ============ starting iteration 16   ============
# Updated S, new gain: 235.9791915884922812990898224
# iteration took: 194.14 ms
# ============ starting iteration 17   ============
# Updated S, new gain: 237.6441050567918787156298374
# iteration took: 666.08 ms
# ============ starting iteration 18   ============
# Updated S, new gain: 239.2926555248186416654526910
# iteration took: 209.17 ms
# ============ starting iteration 19   ============
# Updated S, new gain: 240.9382369307034784884317729
# iteration took: 158.24 ms
# ============ starting iteration 20   ============
# Updated S, new gain: 242.5677953743364799896524511
# iteration took: 133.28 ms
# ============ starting iteration 21   ============
# iteration took: 0.00 ms
# LazyGreedy with type CB finished after 21 iterations
# algorithm took: 7631.65 ms

# %%
df = pd.DataFrame(sample)
df
# Out:
#        _id  bikeid                 start_time  duration_minutes  \
# 0   615446     373  2016-06-12 18:38:54+03:00                13
# 1   615464     352  2014-07-18 08:12:00+03:00                29
# 2   615485     712  2015-07-31 14:12:00+03:00                 5
# 3   615433     894  2015-03-07 16:12:00+02:00                44
# 4   615479     414  2016-05-18 18:31:43+03:00                 3
# 5   615442     263  2017-01-29 11:04:39+02:00                54
# 6   615523     966  2015-03-18 20:12:00+02:00                 4
# 7   615448     893  2016-09-30 15:38:03+03:00                36
# 8   615498      95  2014-04-26 19:12:00+03:00                 0
# 9   615461     646  2015-12-02 17:12:27+02:00                 7
# 10  615453     282  2014-11-08 21:12:00+02:00               110
# 11  615489     362  2014-04-05 22:12:00+03:00                21
# 12  615508     957  2017-02-11 14:33:53+02:00                24
# 13  615462     774  2017-05-15 16:09:49+03:00                20
# 14  615454     263  2017-04-08 15:43:46+03:00                34
# 15  615441     434  2017-03-19 02:21:45+02:00                63
# 16  615497     224  2015-10-30 14:12:00+02:00                21
# 17  615491     306  2016-06-06 17:50:41+03:00                13
# 18  615486     963  2017-04-07 11:39:40+03:00                12
# 19  615472     610  2015-06-12 16:12:00+03:00                10
#
#                          start_station_name  \
# 0   Convention Center / 4th St. @ MetroRail
# 1         Capitol Station / Congress & 11th
# 2                            4th & Congress
# 3                      Rainey St @ Cummings
# 4             Pfluger Bridge @ W 2nd Street
# 5                  South Congress & Academy
# 6                            4th & Congress
# 7                            2nd & Congress
# 8                  City Hall / Lavaca & 2nd
# 9                               5th & Bowie
# 10                         17th & Guadalupe
# 11                          8th & Guadalupe
# 12        Convention Center / 3rd & Trinity
# 13                             Brazos & 6th
# 14                      Barton Springs Pool
# 15                     Rainey St @ Cummings
# 16        Capitol Station / Congress & 11th
# 17        Capitol Station / Congress & 11th
# 18  Convention Center / 4th St. @ MetroRail
# 19          Bullock Museum @ Congress & MLK
#
#                                      end_station_name  start_latitude  \
# 0                              Davis at Rainey Street        30.26483
# 1                   Capitol Station / Congress & 11th        30.27260
# 2                                         5th & Bowie        30.26634
# 3                                Rainey St @ Cummings        30.25579
# 4                                          3rd & West        30.26717
# 5   South Congress & Barton Springs at the Austin ...        30.25226
# 6             Convention Center / 4th St. @ MetroRail        30.26634
# 7                                      2nd & Congress        30.26408
# 8                            City Hall / Lavaca & 2nd        30.26476
# 9                                   Palmer Auditorium        30.26960
# 10                                     4th & Congress        30.27974
# 11                                   Guadalupe & 21st        30.27106
# 12  South Congress & Barton Springs at the Austin ...        30.26426
# 13                                       Brazos & 6th        30.26754
# 14            Convention Center / 4th St. @ MetroRail        30.26452
# 15                                  Medina & East 6th        30.25579
# 16                           UT West Mall @ Guadalupe        30.27260
# 17                               Rainey St @ Cummings        30.27260
# 18                  Capitol Station / Congress & 11th        30.26483
# 19            Convention Center / 4th St. @ MetroRail        30.28039
#
#     start_longitude  end_latitude  end_longitude
# 0         -97.73900      30.26019      -97.73845
# 1         -97.74127      30.27260      -97.74127
# 2         -97.74378      30.26960      -97.75332
# 3         -97.73982      30.25579      -97.73982
# 4         -97.75484      30.26780      -97.75189
# 5         -97.74854      30.25839      -97.74592
# 6         -97.74378      30.26483      -97.73900
# 7         -97.74355      30.26408      -97.74355
# 8         -97.74678      30.26476      -97.74678
# 9         -97.75332      30.25971      -97.75346
# 10        -97.74254      30.26634      -97.74378
# 11        -97.74563      30.28395      -97.74198
# 12        -97.74023      30.25839      -97.74592
# 13        -97.74154      30.26754      -97.74154
# 14        -97.77120      30.26483      -97.73900
# 15        -97.73982      30.26455      -97.73165
# 16        -97.74127      30.28576      -97.74181
# 17        -97.74127      30.25579      -97.73982
# 18        -97.73900      30.27260      -97.74127
# 19        -97.73809      30.26483      -97.73900

# %%
random_sample = DataAccess().select(f"SELECT * FROM {schema}.{table} ORDER BY RANDOM() LIMIT {saqp_manager.k}")
df2 = pd.DataFrame(random_sample)

# %%
import kmedoids
import numpy as np
from scipy.spatial.distance import pdist, squareform

population = saqp_manager.saqpParAdapter.get_population()
def np_dist(t1, t2):
    keys = [*population[0].keys()]
    t1_dict = {}
    t2_dict = {}
    for i in range(len(t1)):
        t1_dict[keys[i]] = t1[i]
        t2_dict[keys[i]] = t2[i]
    return saqp_manager.saqpParAdapter._tuple_weight(t1_dict) * saqp_manager.saqpParAdapter._dist(t1_dict, t2_dict)

T = np.array([[*d.values()] for d in saqp_manager.saqpParAdapter.get_population()])
distmatrix = squareform(pdist(T, np_dist))
km = kmedoids.fasterpam(distmatrix, saqp_manager.k)
kmedoids_sample = [population[i] for i in list(km.medoids)]
df3 = pd.DataFrame(kmedoids_sample)

# %%
score_func = saqp_manager.saqpParAdapter.get_gain_function()
print(f"Sample score for our sample: {score_func(sample)}")

numRandomTrials = 100
random_score = sum([score_func(DataAccess().select(f"SELECT * FROM {schema}.{table} ORDER BY RANDOM() LIMIT {saqp_manager.k}")) for i in range(numRandomTrials)]) / numRandomTrials

print(f"Sample score for random sample: {random_score}")
print(f"Sample score for kmedoids sample: {score_func(kmedoids_sample)}")
# Out:
# Sample score for our sample: 242.5677953743364799896524511
# Sample score for random sample: 226.8852909126666352455863462
# Sample score for kmedoids sample: 223.2018722924888683468750397

# %%
# TODO here we want data from the histogram to complete the answer of the query over the sample

# %%
import pandasql as ps
import matplotlib.pyplot as plt

dataAccess = DataAccess()
queries = [q['sql'][0].replace("_id", "*") for q in workload]
x = [*range(len(queries))]

sampleY = []
randomY = []
kmedoidsY = []
for query in queries:
    sample_query_df = ps.sqldf(query.replace(f"{schema}.{table}", "df"))
    kmedoids_query_df = ps.sqldf(query.replace(f"{schema}.{table}", "df3"))

    sampleY += [saqp_manager.saqpParAdapter.query_result_score(sample_query_df.to_dict('records'),
                                                               dataAccess.select_to_df(query).to_dict('records'))]
    random_dfs = [DataAccess().select_to_df(f"SELECT * FROM {schema}.{table} ORDER BY RANDOM() LIMIT {saqp_manager.k}") for i in range(numRandomTrials)]
    random_scores = []
    for random_df in random_dfs:
        random_query_df = ps.sqldf(query.replace(f"{schema}.{table}", "random_df"))
        random_scores += [saqp_manager.saqpParAdapter.query_result_score(random_query_df.to_dict('records'),
                                                               dataAccess.select_to_df(query).to_dict('records'))]
    randomY += [(sum(random_scores) / numRandomTrials)]
    kmedoidsY += [saqp_manager.saqpParAdapter.query_result_score(kmedoids_query_df.to_dict('records'),
                                                               dataAccess.select_to_df(query).to_dict('records'))]

plt.bar([t - 0.2 for t in x], sampleY, 0.2, label='Our Sample')
plt.bar([t for t in x], randomY, 0.2, label='Random Sample')
plt.bar([t + 0.2 for t in x], kmedoidsY, 0.2, label='Kmedoids Sample')

plt.xlabel("Queries")
plt.ylabel("Scores")
plt.title("Query Scores")
plt.legend()
plt.show()

# %%
import pandasql as ps
import matplotlib.pyplot as plt

dataAccess = DataAccess()
queries = [q['sql'][0].replace("_id", "*") for q in workload]
x = [*range(len(queries))]

sampleY = []
randomY = []
kmedoidsY = []
truthY = []
for query in queries:
    sample_query_df = ps.sqldf(query.replace(f"{schema}.{table}", "df"))
    kmedoids_query_df = ps.sqldf(query.replace(f"{schema}.{table}", "df3"))
    truth_query_df = dataAccess.select_to_df(query)

    random_dfs = [DataAccess().select_to_df(f"SELECT * FROM {schema}.{table} ORDER BY RANDOM() LIMIT {saqp_manager.k}") for i in range(numRandomTrials)]
    random_scores = []
    for random_df in random_dfs:
        random_query_df = ps.sqldf(query.replace(f"{schema}.{table}", "random_df"))
        random_scores += [len(random_query_df)]

    randomY += [(sum(random_scores) / numRandomTrials)]
    sampleY += [len(sample_query_df.index)]
    kmedoidsY += [len(kmedoids_query_df.index)]
    truthY += [len(truth_query_df.index)]

plt.bar([t - 0.2 for t in x], truthY, 0.1, label='Ground Truth')
plt.bar([t - 0.1 for t in x], sampleY, 0.1, label='Our Sample')
plt.bar([t for t in x], randomY, 0.1, label='Random Sample')
plt.bar([t + 0.1 for t in x], kmedoidsY, 0.1, label='KMedoids Sample')

plt.xlabel("Queries")
plt.ylabel("Num of tuples")
plt.title("Tuples kept for each query")
plt.legend()
plt.show()
