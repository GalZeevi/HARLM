# %%
# %load_ext autoreload
# %autoreload 2

# %%
from asqp_rl_demo import *

# %% [markdown]
# # Questions

# %%
asqp_rl = AsqpInstance()

# %% [markdown]
# ### Database Papers From Selected Universities

# %%
sql = '''
SELECT title,
       YEAR,
       o.name AS organization
FROM organization o,
     publication p,
     publication_organization po,
     domain_publication dp,
     DOMAIN d
WHERE p.pid = po.pid
  AND o.oid = po.oid
  AND dp.pid = p.pid
  AND dp.did = d.did
  AND d.name = 'Databases'
  AND o.name IN ('Tel Aviv University', 'University of Maryland', 'University of Michigan');
'''
asqp_rl.query_asqp(sql)
demonstrate_asqp_rl(asqp_rl)
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;"></h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>title</th>
#       <th>year</th>
#       <th>organization</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Revision provenance in text documents of asynchronous collaboration.</td>
#       <td>2013</td>
#       <td>University of Michigan</td>
#     </tr>
#     <tr>
#       <td>Managing General and Individual Knowledge in Crowd Mining Applications.</td>
#       <td>2015</td>
#       <td>Tel Aviv University</td>
#     </tr>
#     <tr>
#       <td>Auto-completion learning for XML.</td>
#       <td>2012</td>
#       <td>Tel Aviv University</td>
#     </tr>
#     <tr>
#       <td>SWST: A Disk Based Index for Sliding Window Spatio-Temporal Data.</td>
#       <td>2012</td>
#       <td>University of Michigan</td>
#     </tr>
#     <tr>
#       <td>CrowdPlanr: Planning made easy with crowd.</td>
#       <td>2013</td>
#       <td>Tel Aviv University</td>
#     </tr>
#     <tr>
#       <td>Using Markov Chain Monte Carlo to play Trivia.</td>
#       <td>2011</td>
#       <td>Tel Aviv University</td>
#     </tr>
#     <tr>
#       <td>A sample-and-clean framework for fast and accurate query processing on dirty data.</td>
#       <td>2014</td>
#       <td>University of California Berkeley</td>
#     </tr>
#     <tr>
#       <td>Dismantling Complicated Query Attributes with Crowd.</td>
#       <td>2015</td>
#       <td>Tel Aviv University</td>
#     </tr>
#     <tr>
#       <td>CrowdMatcher: crowd-assisted schema matching.</td>
#       <td>2014</td>
#       <td>University of Michigan</td>
#     </tr>
#     <tr>
#       <td>DSH: data sensitive hashing for high-dimensional k-nnsearch.</td>
#       <td>2014</td>
#       <td>University of Michigan</td>
#     </tr>
#     <tr>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <td>A quest for beauty and wealth (or, business processes for database researchers).</td>
#       <td>2011</td>
#       <td>Tel Aviv University</td>
#     </tr>
#     <tr>
#       <td>A sample-and-clean framework for fast and accurate query processing on dirty data.</td>
#       <td>2014</td>
#       <td>Tel Aviv University</td>
#     </tr>
#     <tr>
#       <td>The ACM PODS Alberto O. Mendelzon test-of-time award 2013.</td>
#       <td>2013</td>
#       <td>Tel Aviv University</td>
#     </tr>
#     <tr>
#       <td>Making interval-based clustering rank-aware.</td>
#       <td>2011</td>
#       <td>Tel Aviv University</td>
#     </tr>
#     <tr>
#       <td>Mining the Crowd.</td>
#       <td>2014</td>
#       <td>Tel Aviv University</td>
#     </tr>
#     <tr>
#       <td>Labeling recursive workflow executions on-the-fly.</td>
#       <td>2011</td>
#       <td>Tel Aviv University</td>
#     </tr>
#     <tr>
#       <td>Finding optimal probabilistic generators for XML collections.</td>
#       <td>2012</td>
#       <td>Tel Aviv University</td>
#     </tr>
#     <tr>
#       <td>Enabling Privacy in Provenance-Aware Workflow Systems.</td>
#       <td>2011</td>
#       <td>Tel Aviv University</td>
#     </tr>
#     <tr>
#       <td>OASSIS: query driven crowd mining.</td>
#       <td>2014</td>
#       <td>Tel Aviv University</td>
#     </tr>
#     <tr>
#       <td>Using Data for Systemic Financial Risk Management.</td>
#       <td>2011</td>
#       <td>University of Maryland</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;"></h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>title</th>
#       <th>year</th>
#       <th>organization</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Mastermind is NP-Complete.</td>
#       <td>2005</td>
#       <td>University of Maryland</td>
#     </tr>
#     <tr>
#       <td>A Bayesian Model for Discovering Typological Implications.</td>
#       <td>2009</td>
#       <td>University of Maryland</td>
#     </tr>
#     <tr>
#       <td>The New Jersey Data Reduction Report.</td>
#       <td>1997</td>
#       <td>University of Michigan</td>
#     </tr>
#     <tr>
#       <td>The Unfriending Problem: The Consequences of Homophily in Friendship Retention for Causal Estimates of Social Influence.</td>
#       <td>2010</td>
#       <td>University of Michigan</td>
#     </tr>
#     <tr>
#       <td>Performance Bounds for Sparse Parametric Covariance Estimation in Gaussian Models.</td>
#       <td>2011</td>
#       <td>University of Michigan</td>
#     </tr>
#     <tr>
#       <td>Logic Approach to Knowledge and Data Bases at ECRC.</td>
#       <td>1987</td>
#       <td>University of Maryland</td>
#     </tr>
#     <tr>
#       <td>The Moser-Tardos Framework with Partial Resampling.</td>
#       <td>2014</td>
#       <td>University of Maryland</td>
#     </tr>
#     <tr>
#       <td>Proceedings of the Sixth Conference on Uncertainty in Artificial Intelligence (1990).</td>
#       <td>2013</td>
#       <td>University of Maryland</td>
#     </tr>
#     <tr>
#       <td>Through a Glass Darkly: Information Technology Design, Identity Verification, and Knowledge Contribution in Online Communities.</td>
#       <td>2007</td>
#       <td>University of Maryland</td>
#     </tr>
#     <tr>
#       <td>Team collaboration in virtual worlds.</td>
#       <td>2007</td>
#       <td>University of Michigan</td>
#     </tr>
#     <tr>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <td>1978 New Orleans Data Base Design Workshop Report.</td>
#       <td>1979</td>
#       <td>University of Michigan</td>
#     </tr>
#     <tr>
#       <td>Diffuse Scattering on Graphs.</td>
#       <td>2014</td>
#       <td>University of Michigan</td>
#     </tr>
#     <tr>
#       <td>Nuzzer: A Large-Scale Device-Free Passive Localization System for Wireless Environments.</td>
#       <td>2009</td>
#       <td>University of Maryland</td>
#     </tr>
#     <tr>
#       <td>High-resolution census data: a simple way to make them useful.</td>
#       <td>2003</td>
#       <td>Tel Aviv University</td>
#     </tr>
#     <tr>
#       <td>Dynamic Pricing of Power in Smart-Grid Networks.</td>
#       <td>2012</td>
#       <td>University of Michigan</td>
#     </tr>
#     <tr>
#       <td>Network Cournot Competition.</td>
#       <td>2014</td>
#       <td>University of Maryland</td>
#     </tr>
#     <tr>
#       <td>An Achievable rate region for the $3-$user interference channel based on coset codes.</td>
#       <td>2014</td>
#       <td>University of Michigan</td>
#     </tr>
#     <tr>
#       <td>Maximum Entropy with Maximum J-Divergence Discrimination for Text Classification.</td>
#       <td>2012</td>
#       <td>University of Michigan</td>
#     </tr>
#     <tr>
#       <td>IFIP WG 11.3 Database Security: Research Questions of Current Significance.</td>
#       <td>1992</td>
#       <td>University of Maryland</td>
#     </tr>
#     <tr>
#       <td>Precoded Integer-Forcing Equalization Universally Achieves the MIMO Capacity up to a Constant Gap.</td>
#       <td>2013</td>
#       <td>Tel Aviv University</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>
# VBox(children=(Output(), RadioButtons(options=(('Left: ASQP-RL, Right: DB', 0), ('Left: DB, Right: ASQP-RL', 1…
# Button(description='Reveal answers', style=ButtonStyle())
# Output()

# %% [markdown]
# ### Papers From Selected Authors

# %%
sql = '''
SELECT a.name,
       a.paper_count,
       a.citation_count,
       o.name AS "organization"
FROM author a,
     writes w,
     publication p,
     organization o,
     publication_organization po
WHERE a.aid = w.aid
  AND w.pid = p.pid
  AND p.pid = po.pid
  AND o.oid = po.oid
  AND a.paper_count < 100
  AND a.citation_count > 1000
  AND o.name = 'University of California San Diego'
  AND p.year > 2013;
'''
asqp_rl.query_asqp(sql)
demonstrate_asqp_rl(asqp_rl)
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;"></h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>name</th>
#       <th>paper_count</th>
#       <th>citation_count</th>
#       <th>organization</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Henrique S. Malvar</td>
#       <td>52</td>
#       <td>1915</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>Kilian Q. Weinberger</td>
#       <td>58</td>
#       <td>1109</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>Jan Kautz</td>
#       <td>99</td>
#       <td>1782</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>Arnon Amir</td>
#       <td>54</td>
#       <td>1046</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>Joseph Pasquale</td>
#       <td>64</td>
#       <td>1559</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>Myron Flickner</td>
#       <td>38</td>
#       <td>5584</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>Kenneth Zeger</td>
#       <td>94</td>
#       <td>3186</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>Carla E. Brodley</td>
#       <td>75</td>
#       <td>2866</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>Kristen Grauman</td>
#       <td>97</td>
#       <td>1535</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>David W. McDonald</td>
#       <td>70</td>
#       <td>1561</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <td>Gary J. Sullivan</td>
#       <td>30</td>
#       <td>3344</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>Ram Zamir</td>
#       <td>90</td>
#       <td>2389</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>Michael Bedford Taylor</td>
#       <td>33</td>
#       <td>1312</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>Javier R. Movellan</td>
#       <td>82</td>
#       <td>1615</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>Ramamohan Paturi</td>
#       <td>62</td>
#       <td>1363</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>Joshua B. Tenenbaum</td>
#       <td>75</td>
#       <td>1319</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>Thomas L. Griffiths</td>
#       <td>74</td>
#       <td>1490</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>Vineet Bafna</td>
#       <td>79</td>
#       <td>2353</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>J. Edward Colgate</td>
#       <td>94</td>
#       <td>1327</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>Hovav Shacham</td>
#       <td>63</td>
#       <td>3659</td>
#       <td>University of California San Diego</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;"></h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>name</th>
#       <th>paper_count</th>
#       <th>citation_count</th>
#       <th>organization</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Frederic T. Chong</td>
#       <td>83</td>
#       <td>1037</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>Ilkay Altintas</td>
#       <td>54</td>
#       <td>1062</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>Philippe Bonnet</td>
#       <td>64</td>
#       <td>1368</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>Alin Deutsch</td>
#       <td>76</td>
#       <td>2596</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>Srilatha Manne</td>
#       <td>23</td>
#       <td>1285</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>Chaitanya K. Baru</td>
#       <td>54</td>
#       <td>1082</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>Sanjoy Dasgupta</td>
#       <td>70</td>
#       <td>1318</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>Javier R. Movellan</td>
#       <td>82</td>
#       <td>1615</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>Thierry Turletti</td>
#       <td>91</td>
#       <td>1856</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>James Fogarty</td>
#       <td>62</td>
#       <td>1049</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <td>Xiaolan Zhang</td>
#       <td>52</td>
#       <td>1571</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>John Kubiatowicz</td>
#       <td>82</td>
#       <td>6934</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>Stephen W. Keckler</td>
#       <td>89</td>
#       <td>3940</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>Curt Schurgers</td>
#       <td>47</td>
#       <td>1120</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>Prabal Dutta</td>
#       <td>81</td>
#       <td>1393</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>Carla E. Brodley</td>
#       <td>75</td>
#       <td>2866</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>Myron Flickner</td>
#       <td>38</td>
#       <td>5584</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>Cheng Jin</td>
#       <td>69</td>
#       <td>2068</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>Kristen Grauman</td>
#       <td>97</td>
#       <td>1535</td>
#       <td>University of California San Diego</td>
#     </tr>
#     <tr>
#       <td>Arnon Amir</td>
#       <td>54</td>
#       <td>1046</td>
#       <td>University of California San Diego</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>
# VBox(children=(Output(), RadioButtons(options=(('Left: ASQP-RL, Right: DB', 0), ('Left: DB, Right: ASQP-RL', 1…
# Button(description='Reveal answers', style=ButtonStyle())
# Output()

# %% [markdown]
# # Results

# %%
asqp_rl.reveal_results()
# Out:
# You were correct in 0 out of 2 questions
